# %% [markdown]
# # Histogram

# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 載入資料並刪除價格歷史為空的列
data = pd.read_csv('/Users/yuchingchen/Documents/專題/cleaned_data/short_flight_final.csv')

# 移除包含 NaN 的數據
plot_data = data.dropna(subset=["平均價格_log", "最低價格_log", "最低價格天數", "價格變異_log", "中位數價格_log"])

# 僅選取艙等為經濟艙的資料
plot_data = plot_data[plot_data["艙等"] == "經濟艙"]

min_value = plot_data['最低價格'].min()
print("最低價格的最小值為：", min_value)

# 用布林索引過濾出「最低價格」等於最小值的所有列
rows_with_min_value = plot_data[plot_data['最低價格'] == min_value]

print(rows_with_min_value)
print("最低價格的最小值的數量為：", len(rows_with_min_value))
# Out:
# 最低價格的最小值為： 1340
#             出發日期   星期    出發時間  出發時段 出發機場代號     抵達時間  抵達時段 抵達機場代號  機場分類  \
# 2960  2025-01-20  星期一  下午2:05  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 2962  2025-01-20  星期一  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 2996  2025-01-21  星期二  下午2:05  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 2999  2025-01-21  星期二  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 3006  2025-01-21  星期二  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 3018  2025-01-21  星期二  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 3035  2025-01-22  星期三  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 3038  2025-01-22  星期三  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 3045  2025-01-22  星期三  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 3055  2025-01-22  星期三  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 3068  2025-01-23  星期四  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 3071  2025-01-23  星期四  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 3076  2025-01-23  星期四  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 3086  2025-01-23  星期四  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 3567  2025-02-06  星期四  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 3570  2025-02-06  星期四  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 3589  2025-02-06  星期四  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 3628  2025-02-07  星期五  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 3724  2025-02-10  星期一  下午2:05  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 3727  2025-02-10  星期一  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 3763  2025-02-11  星期二  下午2:05  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 3766  2025-02-11  星期二  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 3773  2025-02-11  星期二  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 3785  2025-02-11  星期二  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 3802  2025-02-12  星期三  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 3805  2025-02-12  星期三  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 3812  2025-02-12  星期三  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 3823  2025-02-12  星期三  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 3840  2025-02-13  星期四  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 3843  2025-02-13  星期四  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 3850  2025-02-13  星期四  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 3862  2025-02-13  星期四  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 3879  2025-02-14  星期五  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 3882  2025-02-14  星期五  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 3889  2025-02-14  星期五  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 3901  2025-02-14  星期五  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 3940  2025-02-15  星期六  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 3997  2025-02-17  星期一  下午2:05  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 4000  2025-02-17  星期一  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 4036  2025-02-18  星期二  下午2:05  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 4039  2025-02-18  星期二  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 4046  2025-02-18  星期二  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 4058  2025-02-18  星期二  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 4075  2025-02-19  星期三  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 4078  2025-02-19  星期三  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 4085  2025-02-19  星期三  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 4096  2025-02-19  星期三  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
# 4113  2025-02-20  星期四  下午2:10  下午班機    TPE   下午4:05  下午抵達    HKG   2.0
# 4116  2025-02-20  星期四  下午2:50  下午班機    TPE   下午4:55  下午抵達    HKG   2.0
# 4123  2025-02-20  星期四  下午5:40  下午班機    TPE   晚上7:35  晚間抵達    HKG   2.0
# 4135  2025-02-20  星期四  晚上9:10  晚間班機    TPE  晚上11:10  晚間抵達    HKG   2.0
#
#         航空公司  ...  筆數 平均價格_log 最低價格_log 價格變異_log  中位數價格_log 最低價格天數  Region  \
# 2960  香港快運航空  ...  85     7.54      7.2    12.84       7.43     30      香港
# 2962  香港快運航空  ...  86     7.53      7.2    12.84       7.43     30      香港
# 2996  香港快運航空  ...  89     7.57      7.2    13.10       7.43     29      香港
# 2999  香港快運航空  ...  91     7.56      7.2    13.22       7.32     29      香港
# 3006  香港快運航空  ...  87     7.58      7.2    12.75       7.50     29      香港
# 3018  香港快運航空  ...  90     7.54      7.2    12.98       7.33     29      香港
# 3035  香港快運航空  ...  86     7.58      7.2    12.78       7.50     28      香港
# 3038  香港快運航空  ...  86     7.53      7.2    12.79       7.37     28      香港
# 3045  香港快運航空  ...  86     7.58      7.2    12.69       7.50     28      香港
# 4123  香港快運航空  ...  87     7.39      7.2    11.86       7.33      0      香港
# 4135  香港快運航空  ...  87     7.36      7.2    11.74       7.33      0      香港
#
#      Cost of Living Index  GDP (PPP) per capita (in thousand USD)  \
# 2960                 70.8                                  71.627
# 2962                 70.8                                  71.627
# 2996                 70.8                                  71.627
# 2999                 70.8                                  71.627
# 3006                 70.8                                  71.627
# 3018                 70.8                                  71.627
# 3035                 70.8                                  71.627
# 3038                 70.8                                  71.627
# 3045                 70.8                                  71.627
# 3055                 70.8                                  71.627
# 3068                 70.8                                  71.627
# 3071                 70.8                                  71.627
# 3076                 70.8                                  71.627
# 3086                 70.8                                  71.627
# 3567                 70.8                                  71.627
# 3570                 70.8                                  71.627
# 3589                 70.8                                  71.627
# 3628                 70.8                                  71.627
# 3724                 70.8                                  71.627
# 3727                 70.8                                  71.627
# 3763                 70.8                                  71.627
# 3766                 70.8                                  71.627
# 3773                 70.8                                  71.627
# 3785                 70.8                                  71.627
# 3802                 70.8                                  71.627
# 3805                 70.8                                  71.627
# 3812                 70.8                                  71.627
# 3823                 70.8                                  71.627
# 3840                 70.8                                  71.627
# 3843                 70.8                                  71.627
# 3850                 70.8                                  71.627
# 3862                 70.8                                  71.627
# 3879                 70.8                                  71.627
# 3882                 70.8                                  71.627
# 3889                 70.8                                  71.627
# 3901                 70.8                                  71.627
# 3940                 70.8                                  71.627
# 3997                 70.8                                  71.627
# 4000                 70.8                                  71.627
# 4036                 70.8                                  71.627
# 4039                 70.8                                  71.627
# 4046                 70.8                                  71.627
# 4058                 70.8                                  71.627
# 4075                 70.8                                  71.627
# 4078                 70.8                                  71.627
# 4085                 70.8                                  71.627
# 4096                 70.8                                  71.627
# 4113                 70.8                                  71.627
# 4116                 70.8                                  71.627
# 4123                 70.8                                  71.627
# 4135                 70.8                                  71.627
#
#      competing_flights
# 2960                21
# 2962                21
# 2996                24
# 2999                24
# 3006                24
# 3018                22
# 3035                22
# 3038                22
# 3045                22
# 3055                19
# 3068                18
# 3071                18
# 3076                18
# 3086                19
# 3567                14
# 3570                14
# 3589                13
# 3628                14
# 3724                15
# 3727                15
# 3763                24
# 3766                24
# 3773                24
# 3785                22
# 3802                16
# 3805                16
# 3812                16
# 3823                13
# 3840                14
# 3843                14
# 3850                14
# 3862                14
# 3879                15
# 3882                15
# 3889                15
# 3901                14
# 3940                12
# 3997                16
# 4000                16
# 4036                16
# 4039                16
# 4046                16
# 4058                15
# 4075                24
# 4078                24
# 4085                24
# 4096                20
# 4113                24
# 4116                24
# 4123                24
# 4135                22
#
# [51 rows x 37 columns]
# 最低價格的最小值的數量為： 51

# %% [markdown]
# **Histogram**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 繁體中文設定
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False

# 創建子圖
fig, axes = plt.subplots(3, 2, figsize=(20, 18))
bins = 50  # 設定直方圖的 bin 數量

# 第一個子圖：平均價格的直方圖
sns.histplot(plot_data['平均價格'], bins=bins, kde=False, color='#FF9999', ax=axes[0, 0])
axes[0, 0].set_title('平均價格的分佈')
axes[0, 0].set_xlabel('平均價格')
axes[0, 0].set_ylabel('頻率')

# 第二個子圖：最低價格的直方圖
sns.histplot(plot_data['最低價格'], bins=bins, kde=False, color='#99CCFF', ax=axes[0, 1])
axes[0, 1].set_title('最低價格的分佈')
axes[0, 1].set_xlabel('最低價格')
axes[0, 1].set_ylabel('頻率')

# 第三個子圖：最低價格剩餘天數的直方圖
sns.histplot(plot_data['最低價格剩餘天數'], bins=bins, kde=False, color='#FFCC99', ax=axes[1, 0])
axes[1, 0].set_title('最低價格剩餘天數的分佈')
axes[1, 0].set_xlabel('最低價格剩餘天數')
axes[1, 0].set_ylabel('頻率')

# 第四個子圖：價格變異的直方圖
sns.histplot(plot_data['價格變異'], bins=bins, kde=False, color='#CCCCFF', ax=axes[1, 1])
axes[1, 1].set_title('價格變異的分佈')
axes[1, 1].set_xlabel('價格變異')
axes[1, 1].set_ylabel('頻率')

# 第五個子圖：中位數的直方圖
sns.histplot(plot_data['中位數價格'], bins=bins, kde=False, color='#B3FFCC', ax=axes[2, 0])
axes[2, 0].set_title('中位數的分佈')
axes[2, 0].set_xlabel('中位數')
axes[2, 0].set_ylabel('頻率')

# 隱藏第六個子圖（無數據）
axes[2, 1].axis('off')

# 調整佈局
plt.tight_layout()
plt.show()

# %% [markdown]
# **處理後：Histogram**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 繁體中文設定
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False

# 創建子圖，分別繪製平均價格（對數）、最低價格（對數）、最低價格剩餘天數（對數）、價格變異（對數）和中位數（對數）的直方圖
fig, axes = plt.subplots(3, 2, figsize=(20, 18))
bins = 50  # 設定直方圖的 bin 數量

# 第一個子圖：平均價格（對數）的直方圖
sns.histplot(plot_data['平均價格_log'], bins=bins, kde=False, color='#FF9999', ax=axes[0, 0])
axes[0, 0].set_title('平均價格（對數）的分佈')
axes[0, 0].set_xlabel('平均價格（對數）')
axes[0, 0].set_ylabel('頻率')

# 第二個子圖：最低價格（對數）的直方圖
sns.histplot(plot_data['最低價格_log'], bins=bins, kde=False, color='#99CCFF', ax=axes[0, 1])
axes[0, 1].set_title('最低價格（對數）的分佈')
axes[0, 1].set_xlabel('最低價格（對數）')
axes[0, 1].set_ylabel('頻率')

# 第三個子圖：最低價格天數的直方圖
sns.histplot(plot_data['最低價格天數'], bins=bins, kde=False, color='#FFCC99', ax=axes[1, 0])
axes[1, 0].set_title('最低價格天數的分佈')
axes[1, 0].set_xlabel('最低價格天數')
axes[1, 0].set_ylabel('頻率')

# 第四個子圖：價格變異（對數）的直方圖
sns.histplot(plot_data['價格變異_log'], bins=bins, kde=False, color='#CCCCFF', ax=axes[1, 1])
axes[1, 1].set_title('價格變異（對數）的分佈')
axes[1, 1].set_xlabel('價格變異（對數）')
axes[1, 1].set_ylabel('頻率')

# 第五個子圖：中位數（對數）的直方圖
sns.histplot(plot_data['中位數價格_log'], bins=bins, kde=False, color='#B3FFCC', ax=axes[2, 0])
axes[2, 0].set_title('中位數（對數）的分佈')
axes[2, 0].set_xlabel('中位數（對數）')
axes[2, 0].set_ylabel('頻率')

# 隱藏第六個子圖（無數據）
axes[2, 1].axis('off')

# 調整佈局
plt.tight_layout()
plt.show()
